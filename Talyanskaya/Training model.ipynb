# %% [markdown]
# # Training model
#
# Note: I have tried several models, starting with handmade 8-layer NN, ending with Resnet18, used by my colleagues, however, all of them failed to perform for different reasons (died VMs, some overtraining, other unknown problems). I do admit using different sources in the web as well as a help of my colleague Alexandr Marinsky and other people, thanks to them.
#
# Finally, I ended with this IncenptionV3-based model with some changes as this model showed not very high but stable results. Originally, this model comes from standard Keras models and was trained on well-known Imagenet datadase.
# The algorithm is rather simple: traing the "Inception part" of NN on our dataset, when save the results as Numpy-arrays, train with this Numpy-arrays the upper layer and than complile and tune model with blicked inner layers.

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.applications.inception_v3 import InceptionV3
from keras.callbacks import ModelCheckpoint
from keras.optimizers import SGD

from keras import backend as K
K.set_image_dim_ordering('th')

import numpy as np
import pandas as pd
import h5py
# Out:
# Using TensorFlow backend.

# %%
inc_model=InceptionV3(include_top=False, 
                      weights='imagenet', 
                      input_shape=(3, 150, 150))

# %%
import zipfile

local_zip = '//jet/prs/workspace/Dataset_iphone_new.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/home/talyanskaya_marina/Dataset_iphone_new')
zip_ref.close()

# %%
bottleneck_datagen = ImageDataGenerator(rescale=1./255)
    
train_generator = bottleneck_datagen.flow_from_directory('/home/talyanskaya_marina/Dataset_iphone_new/Dataset_iphone_new/train',
                                        target_size=(150, 150),
                                        batch_size=32,
                                        class_mode=None,
                                        shuffle=False)

validation_generator = bottleneck_datagen.flow_from_directory('/home/talyanskaya_marina/Dataset_iphone_new/Dataset_iphone_new/validation',
                                                               target_size=(150, 150),
                                                               batch_size=32,
                                                               class_mode=None,
                                                               shuffle=False)
# Out:
# Found 24000 images belonging to 2 classes.
# Found 24000 images belonging to 2 classes.

# %%
import os
import shutil

# %%
try:
    os.mkdir('/home/talyanskaya_marina/bottleneck_features')
except OSError:
    shutil.rmtree('/home/talyanskaya_marina/bottleneck_features')
    os.mkdir('/home/talyanskaya_marina/bottleneck_features')

bottleneck_features_train = inc_model.predict_generator(train_generator, steps = 24000/32)
np.save(open('/home/talyanskaya_marina/bottleneck_features/bn_features_train.npy', 'wb+'), bottleneck_features_train)
bottleneck_features_validation = inc_model.predict_generator(validation_generator, steps = 24000/32)
np.save(open('/home/talyanskaya_marina/bottleneck_features/bn_features_validation.npy', 'wb+'), bottleneck_features_validation)

# %%
train_data = np.load(open('/home/talyanskaya_marina/bottleneck_features/bn_features_train.npy', 'rb'))
train_labels = np.array([0] * 12000 + [1] * 12000) 

validation_data = np.load(open('/home/talyanskaya_marina/bottleneck_features/bn_features_validation.npy', 'rb'))
validation_labels = np.array([0] * 12000 + [1] * 12000)

# %%
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten

# %%
fc_model = Sequential()
fc_model.add(Flatten(input_shape=train_data.shape[1:]))
fc_model.add(Dense(64, activation='relu', name='dense_one'))
fc_model.add(Dropout(0.5, name='dropout_one'))
fc_model.add(Dense(64, activation='relu', name='dense_two'))
fc_model.add(Dropout(0.5, name='dropout_two'))
fc_model.add(Dense(1, activation='sigmoid', name='output'))

fc_model.compile(optimizer='rmsprop', 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# %%
try:
    os.mkdir('/home/talyanskaya_marina/bottleneck_features_and_weights/')
except OSError:
    shutil.rmtree('/home/talyanskaya_marina/bottleneck_features_and_weights/')
    os.mkdir('/home/talyanskaya_marina/bottleneck_features_and_weights/')

# %%
fc_model.fit(train_data, train_labels,
            nb_epoch=50, batch_size=32,
            validation_data=(validation_data, validation_labels))
# Out:
# /jet/var/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Train on 24000 samples, validate on 24000 samples
# Epoch 1/50
# 24000/24000 [==============================] - 9s 359us/step - loss: 1.1693 - acc: 0.5064 - val_loss: 0.6886 - val_acc: 0.5092
# Epoch 2/50
# 24000/24000 [==============================] - 8s 315us/step - loss: 0.7021 - acc: 0.5082 - val_loss: 0.6766 - val_acc: 0.5526
# Epoch 3/50
# 24000/24000 [==============================] - 8s 314us/step - loss: 0.7030 - acc: 0.5096 - val_loss: 0.6861 - val_acc: 0.5312
# Epoch 4/50
# 24000/24000 [==============================] - 8s 332us/step - loss: 0.7024 - acc: 0.5175 - val_loss: 0.6780 - val_acc: 0.5518
# Epoch 5/50
# 24000/24000 [==============================] - 8s 335us/step - loss: 0.6988 - acc: 0.5293 - val_loss: 0.6633 - val_acc: 0.5620
# Epoch 6/50
# 24000/24000 [==============================] - 7s 310us/step - loss: 0.6852 - acc: 0.5499 - val_loss: 0.6066 - val_acc: 0.5982
# Epoch 7/50
# 24000/24000 [==============================] - 8s 314us/step - loss: 0.6269 - acc: 0.5981 - val_loss: 0.5505 - val_acc: 0.7205
# Epoch 8/50
# 24000/24000 [==============================] - 8s 315us/step - loss: 0.5859 - acc: 0.6480 - val_loss: 0.5463 - val_acc: 0.7182
# Epoch 9/50
# 24000/24000 [==============================] - 7s 312us/step - loss: 0.5437 - acc: 0.6846 - val_loss: 0.5141 - val_acc: 0.7465
# Epoch 10/50
# 24000/24000 [==============================] - 8s 316us/step - loss: 0.5200 - acc: 0.7010 - val_loss: 0.4996 - val_acc: 0.7474
# Epoch 11/50
# 24000/24000 [==============================] - 8s 313us/step - loss: 0.4992 - acc: 0.7110 - val_loss: 0.5119 - val_acc: 0.7413
# Epoch 12/50
# 24000/24000 [==============================] - 8s 315us/step - loss: 0.4856 - acc: 0.7175 - val_loss: 0.4963 - val_acc: 0.7568
# Epoch 13/50
# 24000/24000 [==============================] - 8s 316us/step - loss: 0.4790 - acc: 0.7211 - val_loss: 0.4861 - val_acc: 0.7515
# Epoch 14/50
# 24000/24000 [==============================] - 8s 314us/step - loss: 0.4767 - acc: 0.7253 - val_loss: 0.4939 - val_acc: 0.7565
# Epoch 15/50
# 24000/24000 [==============================] - 8s 316us/step - loss: 0.4654 - acc: 0.7290 - val_loss: 0.4920 - val_acc: 0.7580
# Epoch 16/50
# 24000/24000 [==============================] - 8s 317us/step - loss: 0.4569 - acc: 0.7361 - val_loss: 0.4903 - val_acc: 0.7572
# Epoch 17/50
# 24000/24000 [==============================] - 8s 318us/step - loss: 0.4520 - acc: 0.7333 - val_loss: 0.4845 - val_acc: 0.7648
# Epoch 18/50
# 24000/24000 [==============================] - 8s 315us/step - loss: 0.4482 - acc: 0.7382 - val_loss: 0.5104 - val_acc: 0.7603
# Epoch 19/50
# 24000/24000 [==============================] - 8s 314us/step - loss: 0.4467 - acc: 0.7360 - val_loss: 0.5332 - val_acc: 0.7476
# Epoch 20/50
# 24000/24000 [==============================] - 8s 317us/step - loss: 0.4431 - acc: 0.7361 - val_loss: 0.4996 - val_acc: 0.7609
# Epoch 21/50
# 24000/24000 [==============================] - 7s 308us/step - loss: 0.4422 - acc: 0.7422 - val_loss: 0.4990 - val_acc: 0.7588
# Epoch 22/50
# 24000/24000 [==============================] - 8s 317us/step - loss: 0.4398 - acc: 0.7377 - val_loss: 0.5043 - val_acc: 0.7545
# Epoch 23/50
# 24000/24000 [==============================] - 8s 315us/step - loss: 0.4352 - acc: 0.7577 - val_loss: 0.4944 - val_acc: 0.7608
# Epoch 24/50
# 24000/24000 [==============================] - 8s 318us/step - loss: 0.4251 - acc: 0.7613 - val_loss: 0.5256 - val_acc: 0.7556
# Epoch 25/50
# 24000/24000 [==============================] - 7s 312us/step - loss: 0.4244 - acc: 0.7680 - val_loss: 0.5180 - val_acc: 0.7597
# Epoch 26/50
# 24000/24000 [==============================] - 8s 319us/step - loss: 0.4189 - acc: 0.7709 - val_loss: 0.5167 - val_acc: 0.7631
# Epoch 27/50
# 24000/24000 [==============================] - 8s 315us/step - loss: 0.4203 - acc: 0.7712 - val_loss: 0.5160 - val_acc: 0.7606
# Epoch 28/50
# 24000/24000 [==============================] - 8s 316us/step - loss: 0.4111 - acc: 0.7780 - val_loss: 0.5377 - val_acc: 0.7627
# Epoch 29/50
# 24000/24000 [==============================] - 8s 314us/step - loss: 0.4109 - acc: 0.7800 - val_loss: 0.5652 - val_acc: 0.7664
# Epoch 30/50
# 24000/24000 [==============================] - 8s 316us/step - loss: 0.4089 - acc: 0.7808 - val_loss: 0.5344 - val_acc: 0.7570
# Epoch 31/50
# 24000/24000 [==============================] - 8s 313us/step - loss: 0.4074 - acc: 0.7869 - val_loss: 0.5374 - val_acc: 0.7595
# Epoch 32/50
# 24000/24000 [==============================] - 8s 317us/step - loss: 0.4029 - acc: 0.7855 - val_loss: 0.6612 - val_acc: 0.7658
# Epoch 33/50
# 24000/24000 [==============================] - 8s 315us/step - loss: 0.3991 - acc: 0.7882 - val_loss: 0.6722 - val_acc: 0.7573
# Epoch 34/50
# 24000/24000 [==============================] - 8s 314us/step - loss: 0.3963 - acc: 0.7907 - val_loss: 0.6105 - val_acc: 0.7577
# Epoch 35/50
# 24000/24000 [==============================] - 8s 316us/step - loss: 0.3939 - acc: 0.7902 - val_loss: 0.5849 - val_acc: 0.7646
# Epoch 36/50
# 24000/24000 [==============================] - 8s 326us/step - loss: 0.3891 - acc: 0.7923 - val_loss: 0.7010 - val_acc: 0.7629
# Epoch 37/50
# 24000/24000 [==============================] - 8s 317us/step - loss: 0.3886 - acc: 0.7943 - val_loss: 0.6281 - val_acc: 0.7662
# Epoch 38/50
# 24000/24000 [==============================] - 8s 317us/step - loss: 0.3764 - acc: 0.7992 - val_loss: 0.6210 - val_acc: 0.7489
# Epoch 39/50
# 24000/24000 [==============================] - 8s 317us/step - loss: 0.3810 - acc: 0.7967 - val_loss: 0.6037 - val_acc: 0.7420
# Epoch 40/50
# 24000/24000 [==============================] - 8s 318us/step - loss: 0.3807 - acc: 0.8000 - val_loss: 0.6978 - val_acc: 0.7586
# Epoch 41/50
# 24000/24000 [==============================] - 8s 316us/step - loss: 0.3782 - acc: 0.7996 - val_loss: 0.5917 - val_acc: 0.7577
# Epoch 42/50
# 24000/24000 [==============================] - 8s 314us/step - loss: 0.3814 - acc: 0.7963 - val_loss: 0.7144 - val_acc: 0.7621
# Epoch 43/50
# 24000/24000 [==============================] - 8s 316us/step - loss: 0.3806 - acc: 0.7942 - val_loss: 0.6483 - val_acc: 0.7520
# Epoch 44/50
# 24000/24000 [==============================] - 7s 304us/step - loss: 0.3775 - acc: 0.8007 - val_loss: 0.7409 - val_acc: 0.7648
# Epoch 45/50
# 24000/24000 [==============================] - 8s 333us/step - loss: 0.3743 - acc: 0.8003 - val_loss: 0.5713 - val_acc: 0.7562
# Epoch 46/50
# 24000/24000 [==============================] - 8s 334us/step - loss: 0.3717 - acc: 0.8038 - val_loss: 0.6715 - val_acc: 0.7549
# Epoch 47/50
# 24000/24000 [==============================] - 8s 318us/step - loss: 0.3713 - acc: 0.8055 - val_loss: 0.6999 - val_acc: 0.7581
# Epoch 48/50
# 24000/24000 [==============================] - 8s 318us/step - loss: 0.3752 - acc: 0.8033 - val_loss: 0.7368 - val_acc: 0.7597
# Epoch 49/50
# 24000/24000 [==============================] - 7s 312us/step - loss: 0.3629 - acc: 0.8091 - val_loss: 0.7648 - val_acc: 0.7570
# Epoch 50/50
# 24000/24000 [==============================] - 8s 314us/step - loss: 0.3680 - acc: 0.8044 - val_loss: 0.7187 - val_acc: 0.7558

# %%
fc_model.save_weights('/home/talyanskaya_marina/bottleneck_features_and_weights/fc_inception_iphone_250.hdf5') # сохраняем веса

# %%
fc_model.evaluate(validation_data, validation_labels)
# Out:
# 24000/24000 [==============================] - 3s 128us/step
# [0.71865298407276468, 0.75579166666666664]

# %%
weights_filename='/home/talyanskaya_marina/bottleneck_features_and_weights/fc_inception_iphone_250.hdf5'

x = Flatten()(inc_model.output)
x = Dense(64, activation='relu', name='dense_one')(x)
x = Dropout(0.5, name='dropout_one')(x)
x = Dense(64, activation='relu', name='dense_two')(x)
x = Dropout(0.5, name='dropout_two')(x)
top_model=Dense(1, activation='sigmoid', name='output')(x)
finalModel = Model(input=inc_model.input, output=top_model)
# Out:
# /jet/var/python/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ou...)`
#   if __name__ == '__main__':

# %%
weights_filename='/home/talyanskaya_marina/bottleneck_features_and_weights/fc_inception_iphone_250.hdf5'
finalModel.load_weights(weights_filename, by_name=True)

# %%
for layer in inc_model.layers[:205]:
    layer.trainable = False

# %%
import tensorflow as tf
from sklearn.metrics import average_precision_score

def AP(y_true, y_pred):
    return tf.py_func(average_precision_score, (y_true, y_pred), tf.double)

# %%
finalModel.compile(loss='binary_crossentropy',
              optimizer=SGD(lr=1e-4, momentum=0.9),
              metrics=['accuracy', AP])

# %%
try:
    os.mkdir('/home/talyanskaya_marina/new_model_weights/')
except OSError:
    shutil.rmtree('/home/talyanskaya_marina/new_model_weights/')
    os.mkdir('/home/talyanskaya_marina/new_model_weights/')

# %%
filepath="/home/talyanskaya_marina/new_model_weights/weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range = 90,
        width_shift_range = 0.25,
        height_shift_range = 0.25,
        brightness_range = [0.3, 1.5],    
        shear_range = 0.4,
        zoom_range = 0.2,
        vertical_flip = True,
        horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
        '/home/talyanskaya_marina/Dataset_iphone_new/Dataset_iphone_new/train',#'/home/talyanskaya_marina/final_dataset/train',
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
        '/home/talyanskaya_marina/Dataset_iphone_new/Dataset_iphone_new/validation',#'/home/talyanskaya_marina/final_dataset/validation/',
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')


pred_generator=test_datagen.flow_from_directory('/home/talyanskaya_marina/Dataset_iphone_new/Dataset_iphone_new/validation',#'/home/talyanskaya_marina/final_dataset/validation/',
                                                     target_size=(150,150),
                                                     batch_size=100,
                                                     class_mode='binary')
# Out:
# Found 24000 images belonging to 2 classes.
# Found 24000 images belonging to 2 classes.
# Found 24000 images belonging to 2 classes.

# %%
finalModel.fit_generator(
        train_generator,
        samples_per_epoch=24000,
        nb_epoch=100,
        validation_data=validation_generator,
        nb_val_samples=24000,
    callbacks=callbacks_list)

try:
    os.mkdir('/home/talyanskaya_marina/lastModel')
except OSError:
    shutil.rmtree('/home/talyanskaya_marina/lastModel')
    os.mkdir('/home/talyanskaya_marina/lastModel')
finalModel.save('/home/talyanskaya_marina/lastModel/model.hdf5')
# Out:
# /jet/var/python/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   import sys
# /jet/var/python/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=<keras_pre..., callbacks=[<keras.ca..., steps_per_epoch=750, epochs=100, validation_steps=24000)`
#   import sys
# Epoch 1/100
# 750/750 [==============================] - 250s 333ms/step - loss: 0.5139 - acc: 0.7418 - AP: 0.8427 - val_loss: 0.4572 - val_acc: 0.7794 - val_AP: 0.8848
#
# Epoch 00001: val_acc improved from -inf to 0.77942, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-01-0.78.hdf5
# Epoch 2/100
# 750/750 [==============================] - 229s 306ms/step - loss: 0.5099 - acc: 0.7442 - AP: 0.8460 - val_loss: 0.4759 - val_acc: 0.7759 - val_AP: 0.8860
#
# Epoch 00002: val_acc did not improve from 0.77942
# Epoch 3/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.5011 - acc: 0.7524 - AP: 0.8560 - val_loss: 0.4587 - val_acc: 0.7810 - val_AP: 0.8869
#
# Epoch 00003: val_acc improved from 0.77942 to 0.78104, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-03-0.78.hdf5
# Epoch 4/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4912 - acc: 0.7587 - AP: 0.8586 - val_loss: 0.4786 - val_acc: 0.7704 - val_AP: 0.8879
#
# Epoch 00004: val_acc did not improve from 0.78104
# Epoch 5/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4933 - acc: 0.7535 - AP: 0.8553 - val_loss: 0.4468 - val_acc: 0.7772 - val_AP: 0.8867
#
# Epoch 00005: val_acc did not improve from 0.78104
# Epoch 6/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4909 - acc: 0.7546 - AP: 0.8569 - val_loss: 0.4795 - val_acc: 0.7820 - val_AP: 0.8922
#
# Epoch 00006: val_acc improved from 0.78104 to 0.78204, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-06-0.78.hdf5
# Epoch 7/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4934 - acc: 0.7576 - AP: 0.8612 - val_loss: 0.4664 - val_acc: 0.7762 - val_AP: 0.8884
#
# Epoch 00007: val_acc did not improve from 0.78204
# Epoch 8/100
# 750/750 [==============================] - 228s 303ms/step - loss: 0.4846 - acc: 0.7630 - AP: 0.8618 - val_loss: 0.4656 - val_acc: 0.7890 - val_AP: 0.8909
#
# Epoch 00008: val_acc improved from 0.78204 to 0.78896, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-08-0.79.hdf5
# Epoch 9/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4788 - acc: 0.7665 - AP: 0.8651 - val_loss: 0.4964 - val_acc: 0.7772 - val_AP: 0.8907
#
# Epoch 00009: val_acc did not improve from 0.78896
# Epoch 10/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4786 - acc: 0.7655 - AP: 0.8677 - val_loss: 0.4775 - val_acc: 0.7565 - val_AP: 0.8890
#
# Epoch 00010: val_acc did not improve from 0.78896
# Epoch 11/100
# 750/750 [==============================] - 229s 305ms/step - loss: 0.4727 - acc: 0.7735 - AP: 0.8701 - val_loss: 0.4625 - val_acc: 0.7866 - val_AP: 0.8923
#
# Epoch 00011: val_acc did not improve from 0.78896
# Epoch 12/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4673 - acc: 0.7740 - AP: 0.8728 - val_loss: 0.4715 - val_acc: 0.7842 - val_AP: 0.8926
#
# Epoch 00012: val_acc did not improve from 0.78896
# Epoch 13/100
# 750/750 [==============================] - 227s 302ms/step - loss: 0.4718 - acc: 0.7736 - AP: 0.8718 - val_loss: 0.4394 - val_acc: 0.7954 - val_AP: 0.8937
#
# Epoch 00013: val_acc improved from 0.78896 to 0.79538, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-13-0.80.hdf5
# Epoch 14/100
# 750/750 [==============================] - 226s 302ms/step - loss: 0.4636 - acc: 0.7761 - AP: 0.8759 - val_loss: 0.4398 - val_acc: 0.7817 - val_AP: 0.8918
#
# Epoch 00014: val_acc did not improve from 0.79538
# Epoch 15/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4678 - acc: 0.7732 - AP: 0.8728 - val_loss: 0.4579 - val_acc: 0.7978 - val_AP: 0.8945
#
# Epoch 00015: val_acc improved from 0.79538 to 0.79783, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-15-0.80.hdf5
# Epoch 16/100
# 750/750 [==============================] - 229s 306ms/step - loss: 0.4626 - acc: 0.7793 - AP: 0.8765 - val_loss: 0.4520 - val_acc: 0.7980 - val_AP: 0.8949
#
# Epoch 00016: val_acc improved from 0.79783 to 0.79804, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-16-0.80.hdf5
# Epoch 17/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4643 - acc: 0.7807 - AP: 0.8780 - val_loss: 0.4435 - val_acc: 0.7944 - val_AP: 0.8961
#
# Epoch 00017: val_acc did not improve from 0.79804
# Epoch 18/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4608 - acc: 0.7838 - AP: 0.8813 - val_loss: 0.4275 - val_acc: 0.7910 - val_AP: 0.8973
#
# Epoch 00018: val_acc did not improve from 0.79804
# Epoch 19/100
# 750/750 [==============================] - 228s 305ms/step - loss: 0.4534 - acc: 0.7808 - AP: 0.8799 - val_loss: 0.4763 - val_acc: 0.7955 - val_AP: 0.9001
#
# Epoch 00019: val_acc did not improve from 0.79804
# Epoch 20/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4533 - acc: 0.7865 - AP: 0.8808 - val_loss: 0.4417 - val_acc: 0.7714 - val_AP: 0.8932
#
# Epoch 00020: val_acc did not improve from 0.79804
# Epoch 21/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4483 - acc: 0.7863 - AP: 0.8839 - val_loss: 0.4275 - val_acc: 0.7970 - val_AP: 0.8970
#
# Epoch 00021: val_acc did not improve from 0.79804
# Epoch 22/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4516 - acc: 0.7873 - AP: 0.8828 - val_loss: 0.4364 - val_acc: 0.8035 - val_AP: 0.8959
#
# Epoch 00022: val_acc improved from 0.79804 to 0.80354, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-22-0.80.hdf5
# Epoch 23/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4517 - acc: 0.7837 - AP: 0.8844 - val_loss: 0.4464 - val_acc: 0.7952 - val_AP: 0.8948
#
# Epoch 00023: val_acc did not improve from 0.80354
# Epoch 24/100
# 750/750 [==============================] - 228s 305ms/step - loss: 0.4503 - acc: 0.7891 - AP: 0.8865 - val_loss: 0.4428 - val_acc: 0.7893 - val_AP: 0.8968
#
# Epoch 00024: val_acc did not improve from 0.80354
# Epoch 25/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4413 - acc: 0.7898 - AP: 0.8906 - val_loss: 0.4637 - val_acc: 0.7921 - val_AP: 0.8975
#
# Epoch 00025: val_acc did not improve from 0.80354
# Epoch 26/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4412 - acc: 0.7898 - AP: 0.8908 - val_loss: 0.4530 - val_acc: 0.7969 - val_AP: 0.8967
#
# Epoch 00026: val_acc did not improve from 0.80354
# Epoch 27/100
# 750/750 [==============================] - 228s 305ms/step - loss: 0.4374 - acc: 0.7943 - AP: 0.8888 - val_loss: 0.4636 - val_acc: 0.8064 - val_AP: 0.9009
#
# Epoch 00027: val_acc improved from 0.80354 to 0.80642, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-27-0.81.hdf5
# Epoch 28/100
# 750/750 [==============================] - 230s 307ms/step - loss: 0.4403 - acc: 0.7905 - AP: 0.8919 - val_loss: 0.4278 - val_acc: 0.7989 - val_AP: 0.9003
#
# Epoch 00028: val_acc did not improve from 0.80642
# Epoch 29/100
# 750/750 [==============================] - 228s 305ms/step - loss: 0.4307 - acc: 0.7981 - AP: 0.8956 - val_loss: 0.4953 - val_acc: 0.8008 - val_AP: 0.8972
#
# Epoch 00029: val_acc did not improve from 0.80642
# Epoch 30/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4278 - acc: 0.7982 - AP: 0.8980 - val_loss: 0.4825 - val_acc: 0.7950 - val_AP: 0.8969
#
# Epoch 00030: val_acc did not improve from 0.80642
# Epoch 31/100
# 750/750 [==============================] - 228s 305ms/step - loss: 0.4274 - acc: 0.8006 - AP: 0.8965 - val_loss: 0.4449 - val_acc: 0.7927 - val_AP: 0.8959
#
# Epoch 00031: val_acc did not improve from 0.80642
# Epoch 32/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4318 - acc: 0.8026 - AP: 0.8973 - val_loss: 0.4842 - val_acc: 0.8030 - val_AP: 0.8979
#
# Epoch 00032: val_acc did not improve from 0.80642
# Epoch 33/100
# 750/750 [==============================] - 226s 301ms/step - loss: 0.4361 - acc: 0.7950 - AP: 0.8922 - val_loss: 0.4746 - val_acc: 0.7870 - val_AP: 0.8943
#
# Epoch 00033: val_acc did not improve from 0.80642
# Epoch 34/100
# 750/750 [==============================] - 229s 305ms/step - loss: 0.4274 - acc: 0.8005 - AP: 0.8978 - val_loss: 0.4479 - val_acc: 0.8001 - val_AP: 0.8970
#
# Epoch 00034: val_acc did not improve from 0.80642
# Epoch 35/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4270 - acc: 0.7986 - AP: 0.8962 - val_loss: 0.4520 - val_acc: 0.7974 - val_AP: 0.8968
#
# Epoch 00035: val_acc did not improve from 0.80642
# Epoch 36/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4263 - acc: 0.8017 - AP: 0.8973 - val_loss: 0.4809 - val_acc: 0.7960 - val_AP: 0.8984
#
# Epoch 00036: val_acc did not improve from 0.80642
# Epoch 37/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4237 - acc: 0.8022 - AP: 0.8982 - val_loss: 0.4509 - val_acc: 0.7725 - val_AP: 0.8929
#
# Epoch 00037: val_acc did not improve from 0.80642
# Epoch 38/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4232 - acc: 0.8045 - AP: 0.9005 - val_loss: 0.4754 - val_acc: 0.8043 - val_AP: 0.9002
#
# Epoch 00038: val_acc did not improve from 0.80642
# Epoch 39/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4227 - acc: 0.8059 - AP: 0.9006 - val_loss: 0.4247 - val_acc: 0.7912 - val_AP: 0.8995
#
# Epoch 00039: val_acc did not improve from 0.80642
# Epoch 40/100
# 750/750 [==============================] - 229s 305ms/step - loss: 0.4201 - acc: 0.8098 - AP: 0.9018 - val_loss: 0.4620 - val_acc: 0.7816 - val_AP: 0.8972
#
# Epoch 00040: val_acc did not improve from 0.80642
# Epoch 41/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4161 - acc: 0.8109 - AP: 0.9025 - val_loss: 0.4234 - val_acc: 0.7886 - val_AP: 0.8980
#
# Epoch 00041: val_acc did not improve from 0.80642
# Epoch 42/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4124 - acc: 0.8065 - AP: 0.9059 - val_loss: 0.4238 - val_acc: 0.8027 - val_AP: 0.9019
#
# Epoch 00042: val_acc did not improve from 0.80642
# Epoch 43/100
# 750/750 [==============================] - 226s 302ms/step - loss: 0.4178 - acc: 0.8094 - AP: 0.9014 - val_loss: 0.4229 - val_acc: 0.7955 - val_AP: 0.8981
#
# Epoch 00043: val_acc did not improve from 0.80642
# Epoch 44/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4145 - acc: 0.8071 - AP: 0.9032 - val_loss: 0.4363 - val_acc: 0.7953 - val_AP: 0.8985
#
# Epoch 00044: val_acc did not improve from 0.80642
# Epoch 45/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4122 - acc: 0.8088 - AP: 0.9059 - val_loss: 0.4224 - val_acc: 0.8003 - val_AP: 0.9001
#
# Epoch 00045: val_acc did not improve from 0.80642
# Epoch 46/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4132 - acc: 0.8069 - AP: 0.9046 - val_loss: 0.4412 - val_acc: 0.8000 - val_AP: 0.8990
#
# Epoch 00046: val_acc did not improve from 0.80642
# Epoch 47/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4094 - acc: 0.8085 - AP: 0.9074 - val_loss: 0.4392 - val_acc: 0.8057 - val_AP: 0.8998
#
# Epoch 00047: val_acc did not improve from 0.80642
# Epoch 48/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4046 - acc: 0.8139 - AP: 0.9100 - val_loss: 0.4467 - val_acc: 0.8014 - val_AP: 0.9029
#
# Epoch 00048: val_acc did not improve from 0.80642
# Epoch 49/100
# 750/750 [==============================] - 229s 305ms/step - loss: 0.4047 - acc: 0.8141 - AP: 0.9096 - val_loss: 0.4219 - val_acc: 0.8044 - val_AP: 0.9018
#
# Epoch 00049: val_acc did not improve from 0.80642
# Epoch 50/100
# 750/750 [==============================] - 228s 303ms/step - loss: 0.4059 - acc: 0.8180 - AP: 0.9083 - val_loss: 0.4420 - val_acc: 0.8040 - val_AP: 0.9011
#
# Epoch 00050: val_acc did not improve from 0.80642
# Epoch 51/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.4007 - acc: 0.8139 - AP: 0.9119 - val_loss: 0.4532 - val_acc: 0.7904 - val_AP: 0.8985
#
# Epoch 00051: val_acc did not improve from 0.80642
# Epoch 52/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.4021 - acc: 0.8185 - AP: 0.9135 - val_loss: 0.4696 - val_acc: 0.8017 - val_AP: 0.8993
#
# Epoch 00052: val_acc did not improve from 0.80642
# Epoch 53/100
# 750/750 [==============================] - 224s 299ms/step - loss: 0.3972 - acc: 0.8185 - AP: 0.9131 - val_loss: 0.4419 - val_acc: 0.7968 - val_AP: 0.9008
#
# Epoch 00053: val_acc did not improve from 0.80642
# Epoch 54/100
# 750/750 [==============================] - 227s 302ms/step - loss: 0.4021 - acc: 0.8180 - AP: 0.9120 - val_loss: 0.4215 - val_acc: 0.8007 - val_AP: 0.9012
#
# Epoch 00054: val_acc did not improve from 0.80642
# Epoch 55/100
# 750/750 [==============================] - 235s 314ms/step - loss: 0.3982 - acc: 0.8229 - AP: 0.9137 - val_loss: 0.4391 - val_acc: 0.8055 - val_AP: 0.8996
#
# Epoch 00055: val_acc did not improve from 0.80642
# Epoch 56/100
# 750/750 [==============================] - 237s 316ms/step - loss: 0.4037 - acc: 0.8165 - AP: 0.9107 - val_loss: 0.4348 - val_acc: 0.7971 - val_AP: 0.8993
#
# Epoch 00056: val_acc did not improve from 0.80642
# Epoch 57/100
# 750/750 [==============================] - 230s 307ms/step - loss: 0.3947 - acc: 0.8200 - AP: 0.9131 - val_loss: 0.4387 - val_acc: 0.8079 - val_AP: 0.9012
#
# Epoch 00057: val_acc improved from 0.80642 to 0.80792, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-57-0.81.hdf5
# Epoch 58/100
# 750/750 [==============================] - 229s 305ms/step - loss: 0.3989 - acc: 0.8192 - AP: 0.9120 - val_loss: 0.4329 - val_acc: 0.8007 - val_AP: 0.9038
#
# Epoch 00058: val_acc did not improve from 0.80792
# Epoch 59/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.3963 - acc: 0.8220 - AP: 0.9131 - val_loss: 0.4789 - val_acc: 0.8097 - val_AP: 0.9026
#
# Epoch 00059: val_acc improved from 0.80792 to 0.80967, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-59-0.81.hdf5
# Epoch 60/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.3937 - acc: 0.8196 - AP: 0.9150 - val_loss: 0.4388 - val_acc: 0.8044 - val_AP: 0.9028
#
# Epoch 00060: val_acc did not improve from 0.80967
# Epoch 61/100
# 750/750 [==============================] - 232s 309ms/step - loss: 0.3928 - acc: 0.8233 - AP: 0.9148 - val_loss: 0.4472 - val_acc: 0.8066 - val_AP: 0.9009
#
# Epoch 00061: val_acc did not improve from 0.80967
# Epoch 62/100
# 750/750 [==============================] - 230s 306ms/step - loss: 0.3971 - acc: 0.8209 - AP: 0.9134 - val_loss: 0.4562 - val_acc: 0.8035 - val_AP: 0.9006
#
# Epoch 00062: val_acc did not improve from 0.80967
# Epoch 63/100
# 750/750 [==============================] - 231s 308ms/step - loss: 0.3912 - acc: 0.8228 - AP: 0.9157 - val_loss: 0.4293 - val_acc: 0.8060 - val_AP: 0.9001
#
# Epoch 00063: val_acc did not improve from 0.80967
# Epoch 64/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.3880 - acc: 0.8220 - AP: 0.9161 - val_loss: 0.4603 - val_acc: 0.8113 - val_AP: 0.9013
#
# Epoch 00064: val_acc improved from 0.80967 to 0.81125, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-64-0.81.hdf5
# Epoch 65/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.3873 - acc: 0.8223 - AP: 0.9167 - val_loss: 0.4635 - val_acc: 0.8043 - val_AP: 0.9012
#
# Epoch 00065: val_acc did not improve from 0.81125
# Epoch 66/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.3874 - acc: 0.8280 - AP: 0.9184 - val_loss: 0.4335 - val_acc: 0.8006 - val_AP: 0.9029
#
# Epoch 00066: val_acc did not improve from 0.81125
# Epoch 67/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.3872 - acc: 0.8260 - AP: 0.9180 - val_loss: 0.4298 - val_acc: 0.7970 - val_AP: 0.9005
#
# Epoch 00067: val_acc did not improve from 0.81125
# Epoch 68/100
# 750/750 [==============================] - 226s 302ms/step - loss: 0.3862 - acc: 0.8266 - AP: 0.9192 - val_loss: 0.4452 - val_acc: 0.8109 - val_AP: 0.9054
#
# Epoch 00068: val_acc did not improve from 0.81125
# Epoch 69/100
# 750/750 [==============================] - 227s 302ms/step - loss: 0.3841 - acc: 0.8291 - AP: 0.9195 - val_loss: 0.4446 - val_acc: 0.7977 - val_AP: 0.8996
#
# Epoch 00069: val_acc did not improve from 0.81125
# Epoch 70/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.3856 - acc: 0.8282 - AP: 0.9192 - val_loss: 0.4786 - val_acc: 0.8095 - val_AP: 0.8999
#
# Epoch 00070: val_acc did not improve from 0.81125
# Epoch 71/100
# 750/750 [==============================] - 225s 300ms/step - loss: 0.3864 - acc: 0.8276 - AP: 0.9190 - val_loss: 0.4501 - val_acc: 0.8095 - val_AP: 0.9046
#
# Epoch 00071: val_acc did not improve from 0.81125
# Epoch 72/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.3810 - acc: 0.8245 - AP: 0.9205 - val_loss: 0.4365 - val_acc: 0.8054 - val_AP: 0.9019
#
# Epoch 00072: val_acc did not improve from 0.81125
# Epoch 73/100
# 750/750 [==============================] - 228s 303ms/step - loss: 0.3811 - acc: 0.8251 - AP: 0.9186 - val_loss: 0.4793 - val_acc: 0.8050 - val_AP: 0.8994
#
# Epoch 00073: val_acc did not improve from 0.81125
# Epoch 74/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.3750 - acc: 0.8315 - AP: 0.9226 - val_loss: 0.4352 - val_acc: 0.8058 - val_AP: 0.8994
#
# Epoch 00074: val_acc did not improve from 0.81125
# Epoch 75/100
# 750/750 [==============================] - 229s 305ms/step - loss: 0.3757 - acc: 0.8317 - AP: 0.9219 - val_loss: 0.4895 - val_acc: 0.7990 - val_AP: 0.9010
#
# Epoch 00075: val_acc did not improve from 0.81125
# Epoch 76/100
# 750/750 [==============================] - 235s 313ms/step - loss: 0.3792 - acc: 0.8289 - AP: 0.9206 - val_loss: 0.4686 - val_acc: 0.8027 - val_AP: 0.9004
#
# Epoch 00076: val_acc did not improve from 0.81125
# Epoch 77/100
# 750/750 [==============================] - 233s 311ms/step - loss: 0.3725 - acc: 0.8354 - AP: 0.9258 - val_loss: 0.4697 - val_acc: 0.8102 - val_AP: 0.9000
#
# Epoch 00077: val_acc did not improve from 0.81125
# Epoch 78/100
# 750/750 [==============================] - 233s 311ms/step - loss: 0.3749 - acc: 0.8331 - AP: 0.9231 - val_loss: 0.4576 - val_acc: 0.8127 - val_AP: 0.9021
#
# Epoch 00078: val_acc improved from 0.81125 to 0.81275, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-78-0.81.hdf5
# Epoch 79/100
# 750/750 [==============================] - 229s 305ms/step - loss: 0.3707 - acc: 0.8354 - AP: 0.9258 - val_loss: 0.4560 - val_acc: 0.8136 - val_AP: 0.9041
#
# Epoch 00079: val_acc improved from 0.81275 to 0.81363, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-79-0.81.hdf5
# Epoch 80/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.3767 - acc: 0.8310 - AP: 0.9218 - val_loss: 0.4510 - val_acc: 0.8017 - val_AP: 0.8998
#
# Epoch 00080: val_acc did not improve from 0.81363
# Epoch 81/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.3725 - acc: 0.8326 - AP: 0.9249 - val_loss: 0.4572 - val_acc: 0.8076 - val_AP: 0.8998
#
# Epoch 00081: val_acc did not improve from 0.81363
# Epoch 82/100
# 750/750 [==============================] - 231s 308ms/step - loss: 0.3743 - acc: 0.8295 - AP: 0.9218 - val_loss: 0.4514 - val_acc: 0.8115 - val_AP: 0.9043
#
# Epoch 00082: val_acc did not improve from 0.81363
# Epoch 83/100
# 750/750 [==============================] - 232s 309ms/step - loss: 0.3642 - acc: 0.8360 - AP: 0.9262 - val_loss: 0.4420 - val_acc: 0.8072 - val_AP: 0.9027
#
# Epoch 00083: val_acc did not improve from 0.81363
# Epoch 84/100
# 750/750 [==============================] - 230s 307ms/step - loss: 0.3701 - acc: 0.8372 - AP: 0.9256 - val_loss: 0.4545 - val_acc: 0.8102 - val_AP: 0.9003
#
# Epoch 00084: val_acc did not improve from 0.81363
# Epoch 85/100
# 750/750 [==============================] - 230s 306ms/step - loss: 0.3703 - acc: 0.8342 - AP: 0.9252 - val_loss: 0.4585 - val_acc: 0.7995 - val_AP: 0.9008
#
# Epoch 00085: val_acc did not improve from 0.81363
# Epoch 86/100
# 750/750 [==============================] - 227s 302ms/step - loss: 0.3710 - acc: 0.8337 - AP: 0.9249 - val_loss: 0.4479 - val_acc: 0.8047 - val_AP: 0.9024
#
# Epoch 00086: val_acc did not improve from 0.81363
# Epoch 87/100
# 750/750 [==============================] - 229s 305ms/step - loss: 0.3647 - acc: 0.8370 - AP: 0.9266 - val_loss: 0.4416 - val_acc: 0.8076 - val_AP: 0.9039
#
# Epoch 00087: val_acc did not improve from 0.81363
# Epoch 88/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.3680 - acc: 0.8345 - AP: 0.9257 - val_loss: 0.4616 - val_acc: 0.8116 - val_AP: 0.9029
#
# Epoch 00088: val_acc did not improve from 0.81363
# Epoch 89/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.3653 - acc: 0.8404 - AP: 0.9273 - val_loss: 0.4458 - val_acc: 0.8122 - val_AP: 0.9052
#
# Epoch 00089: val_acc did not improve from 0.81363
# Epoch 90/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.3550 - acc: 0.8415 - AP: 0.9331 - val_loss: 0.4564 - val_acc: 0.8140 - val_AP: 0.9041
#
# Epoch 00090: val_acc improved from 0.81363 to 0.81400, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-90-0.81.hdf5
# Epoch 91/100
# 750/750 [==============================] - 230s 306ms/step - loss: 0.3587 - acc: 0.8390 - AP: 0.9289 - val_loss: 0.4524 - val_acc: 0.8095 - val_AP: 0.9028
#
# Epoch 00091: val_acc did not improve from 0.81400
# Epoch 92/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.3595 - acc: 0.8409 - AP: 0.9285 - val_loss: 0.4600 - val_acc: 0.8116 - val_AP: 0.9075
#
# Epoch 00092: val_acc did not improve from 0.81400
# Epoch 93/100
# 750/750 [==============================] - 226s 302ms/step - loss: 0.3647 - acc: 0.8360 - AP: 0.9281 - val_loss: 0.4696 - val_acc: 0.8080 - val_AP: 0.9003
#
# Epoch 00093: val_acc did not improve from 0.81400
# Epoch 94/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.3588 - acc: 0.8421 - AP: 0.9299 - val_loss: 0.4484 - val_acc: 0.8090 - val_AP: 0.9040
#
# Epoch 00094: val_acc did not improve from 0.81400
# Epoch 95/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.3589 - acc: 0.8387 - AP: 0.9289 - val_loss: 0.4430 - val_acc: 0.8126 - val_AP: 0.9044
#
# Epoch 00095: val_acc did not improve from 0.81400
# Epoch 96/100
# 750/750 [==============================] - 227s 303ms/step - loss: 0.3596 - acc: 0.8386 - AP: 0.9274 - val_loss: 0.4870 - val_acc: 0.8156 - val_AP: 0.9032
#
# Epoch 00096: val_acc improved from 0.81400 to 0.81563, saving model to /home/talyanskaya_marina/new_model_weights/weights-improvement-96-0.82.hdf5
# Epoch 97/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.3621 - acc: 0.8404 - AP: 0.9290 - val_loss: 0.4139 - val_acc: 0.8125 - val_AP: 0.9056
#
# Epoch 00097: val_acc did not improve from 0.81563
# Epoch 98/100
# 750/750 [==============================] - 229s 305ms/step - loss: 0.3600 - acc: 0.8397 - AP: 0.9294 - val_loss: 0.4225 - val_acc: 0.8122 - val_AP: 0.9050
#
# Epoch 00098: val_acc did not improve from 0.81563
# Epoch 99/100
# 750/750 [==============================] - 227s 302ms/step - loss: 0.3568 - acc: 0.8392 - AP: 0.9296 - val_loss: 0.4410 - val_acc: 0.8113 - val_AP: 0.9072
#
# Epoch 00099: val_acc did not improve from 0.81563
# Epoch 100/100
# 750/750 [==============================] - 228s 304ms/step - loss: 0.3546 - acc: 0.8436 - AP: 0.9318 - val_loss: 0.4489 - val_acc: 0.8107 - val_AP: 0.9059
#
# Epoch 00100: val_acc did not improve from 0.81563

# %% [markdown]
# # Input - output funcion

# %%
import argparse
import keras
import os
from keras.preprocessing.image import ImageDataGenerator
import pandas as pd
    
localPath = os.getenv("PWD")
#os.chdir('/home/talyanskaya_marina/finalFolder')
#localPath = os.getcwd()

def makeYourPredictions(inPath, modelPath, outPath):

    model = keras.models.load_model(modelPath)
    
    finalTest_datagen = ImageDataGenerator(rescale=1./255)

    finalTest_generator = finalTest_datagen.flow_from_directory(inPath,
                                            target_size=(150, 150),
                                            batch_size=32,
                                            class_mode='binary',
                                            shuffle=False)
    
    inFiles = finalTest_generator.filenames;
    
    finalPredictions = model.predict_generator(finalTest_generator, steps=len(inFiles)/32).flatten();
      
    out_df = pd.DataFrame()
    out_df['image_name'] = inFiles
    out_df['iphone_probability'] = finalPredictions
    out_df.to_csv(outPath + 'yourPredictions.csv', index=False)

if __name__ == '__main__':

    parser = argparse.ArgumentParser(description='Iphone detector')
    parser.add_argument('-i', type=str, default=localPath + '/in_folder')#)default='/home/talyanskaya_marina/data main/data/final test/test')
    parser.add_argument('-m', type=str, default=localPath + '/model.hdf5') #default='/home/talyanskaya_marina/savedModel-82/model-82.hdf5')
    parser.add_argument('-o', type=str, default=localPath + '/')#default='/home/talyanskaya_marina/YourPredictionsOutput')
    parser.add_argument('-f', type=str, default='nthg')
    args = parser.parse_args()

    makeYourPredictions(args.i, args.m, args.o)
    
    
    #If we want to write down results in .txt file:
    #try:
    #    os.mkdir(outPath)
    #except OSError:
    #    shutil.rmtree(outPath)
    #    os.mkdir(outPath)
    #finalPath = outPath + '/yourPredictions.txt';

    #f = open(finalPath,'w+');
    
    #for i in range(finalPredictions.shape[0]):
    #    f.write('Probability of ' + inFiles[i] + ' img is iphone is ' + str(round(finalPredictions[i], 2)) + '\n');
        
    #close(f)
# Out:
# Found 750 images belonging to 1 classes.

# %%
df = pd.read_csv('/home/talyanskaya_marina/finalFolder/yourPredictions.csv')
df['decision']=round(df['iphone_probability'])
sum(df['decision'])
# Out:
# 145.0
